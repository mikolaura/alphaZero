# %%
import torch
import matplotlib.pyplot as plt

# %%
from PIL import Image
import requests
from io import BytesIO
response = requests.get("https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcSd4y7zVmHqMDDZPFYCAtIvlWWGYofVYEwNg4AyzbXsRg&s")
plt.imshow(Image.open(BytesIO(response.content)))
